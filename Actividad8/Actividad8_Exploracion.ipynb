# %%
from scipy.integrate import odeint
import numpy as np

def vectorfield(w, t, p):
    """
    Arguments:
        w :  vector of the state variables:
                  w = [x,y]
        t :  time
        p :  vector of the parameters:
                  p = [mu]
    """
    x, y = w

    # Create f = (x',y'):
    f = [y,
         (p*(1.0 - x**2.0) * y) - x]
    return f

# %%
# ****************** mu=0.0 *******************
mu=0.001
x = -2.0
y = 4.0


stoptime = 100
numpoints = 3000

t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

w0 = [x, y]

wsol = odeint(vectorfield, w0, t, args=(mu,))

with open('Xplor_2', 'w') as f:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], file=f)

# %%
mu=.001
x = -3.0
y = -3.0


stoptime = 100
numpoints = 3000

t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

w0 = [x, y]

wsol = odeint(vectorfield, w0, t, args=(mu,))

with open('Xplor_X.dat', 'w') as f:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], file=f)

# %%
mu=.001
x = -1.0
y = -2.0


stoptime = 100
numpoints = 3000

t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
w0 = [x, y]

# Call the ODE solver.
wsol = odeint(vectorfield, w0, t, args=(mu,))

with open('Xplor_Y.dat', 'w') as f:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], file=f)

# %%
mu=.001

x = 1.0
y = 2.0


stoptime = 100
numpoints = 3000

t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

w0 = [x, y]

wsol = odeint(vectorfield, w0, t, args=(mu,))

with open('Xplor_Z.dat', 'w') as f:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], file=f)

# %%
import matplotlib as mpl
from numpy import loadtxt
from pylab import figure, plot, ylabel, xlabel, grid, hold, legend, title, savefig, ylim, xlim
from matplotlib.font_manager import FontProperties
# %matplotlib inline


#t, x, y = loadtxt('Xplor_2', unpack=True)
#plot(x,y,'b')

t, x, y = loadtxt('Xplor_X.dat', unpack=True)
plot(x,y,'b')

t, x, y = loadtxt('Xplor_Y.dat', unpack=True)
plot(x,y,'b')

t, x, y = loadtxt('Xplor_Z.dat', unpack=True)
plot(x,y,'b')

t, x, y = loadtxt('Xplor_2', unpack=True, skiprows=150)
plot(x,y,'r', linewidth=0.5)

xlim(-6,6)
ylim(-6,6)
grid(True)
mpl.pyplot.axis('on')
savefig('Figxploremu_.001.png', dpi=100)

# %%
mu = 0.0
x = 4.0
y = 4.0

stoptime = 100
numpoints = 3000

t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
w0 = [x, y]


wsol = odeint(vectorfield, w0, t, args=(mu,))

with open('Xplor_relax.dat', 'w') as f:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], file=f)

# %%
# Gráfica de "Relaxation oscillation in the Van der Pol oscillator without external forcing"

from numpy import loadtxt
from pylab import figure, plot, ylabel, xlabel, grid, hold, legend, title, savefig, ylim, xlim
from matplotlib.font_manager import FontProperties
# %matplotlib inline

t, x, y = loadtxt('Xplor_relax.dat', unpack=True)

figure(1, figsize=(12, 2))

ylabel('$x_1$')
xlabel('t')
grid(True)
#hold(True)
lw = 2

ylim(-10, 10)
xlim(0,100)

plot(t, x, 'green', linewidth=lw)

savefig('FiguraXplore.png', dpi=100)
